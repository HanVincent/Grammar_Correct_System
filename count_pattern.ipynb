# %%
from get_data import *
from collections import Counter, defaultdict
from pprint import pprint
from operator import itemgetter
import nltk
import numpy as np
import spacy
import explacy # https://github.com/tylerneylon/explacy
# explacy.print_parse_info(nlp, line)

# %%
nlp = spacy.load('en_core_web_lg') # ('en')

# %% [markdown]
# ## 從 BNC 中取得有 discuss 的句子
# * read all lines
# * strip() and lower()
# * filter out target sentences
# * ** Use list() to keep filter generator **

# %%
def clean_data(file, reserved=None):
    lines = map(lambda line: line.strip().lower(), open(file, 'r', encoding='utf8'))
    remains = filter(lambda line: reserved in line, lines) if reserved else lines
    return list(remains)

# %%
remains = clean_data('../dataset/bnc.txt', 'discuss')
remains = list(map(lambda line: nlp(line), remains))

# %% [markdown]
# ## 針對含有 discuss 單字的句子做處理，產生正確與錯誤的資料

# %%
discuss_remains = clean_data('../dataset/efcamp/ef.diff.simplize.despace.txt', 'discuss')

rights, wrongs = [], []
for line in discuss_remains:
    tokens = line.split(' ')
    
    has_edit = False
    for i, tk in enumerate(tokens):
        if tk[:2] in ['[-', '{+'] and 'discuss' in tokens[i-1]:
            has_edit = True
            
    if has_edit:
        wrongs.append((nlp(' '.join(to_before(tokens))), False))
    rights.append((nlp(' '.join(to_after(tokens))), True))

# %%
rights[:3]
# Out:
# [(your family should discuss about my suggestion and we should find a date for a meeting in your favourite objects .,
#   True),
#  (i m writing to discuss about the cards that we are selling ., True),
#  (therefore we could set up a meeting to discuss this issue and settling it out of court .,
#   True)]

# %% [markdown]
# ## Count bigram and trigram
# * **NO** stemming or other processsing
# * split only by **space**

# %%
def get_bi_tri(sents):
    bigrams = Counter([' '.join(bi) for sent in sents for bi in nltk.bigrams(sent.split(' '))])
    trigrams = Counter([' '.join(tri) for sent in sents for tri in nltk.trigrams(sent.split(' '))])

    return bigrams, trigrams

# %%
# bigrams, trigrams = get_bi_tri(remains)

# %%
def get_high_freq(counts):
    values = list(counts.values())
    total, avg, std = np.sum(values), np.mean(values), np.std(values)
    print("Total: {}, Avg: {}, Std: {}".format(total, avg, std))

    return dict([(ngram, count) for ngram, count in counts.items() 
                 if count > avg])

def sort_dict(counts):
    return sorted(counts.items(), key=itemgetter(1), reverse=True)

# %%
# bigram_counts = dict([(ngram, count) for ngram, count in bigrams.items() if ngram.startswith('discuss')])
# trigram_counts = dict([(ngram, count) for ngram, count in trigrams.items() if ngram.startswith('discuss')])
# bigram_counts = get_high_freq(bigram_counts)
# trigram_counts = get_high_freq(trigram_counts)

# %%
def is_past_passive(main_verb):
    if main_verb.tag_ != 'VBN':
        return False
    
    return any([child.lemma_ == 'be' for child in main_verb.children])

def ptn_transform(token):
    if token.tag_ == 'IN':
        return token.text
    elif token.tag_ == 'VBN':
        return 'VBN'
    elif token.tag_.startswith('VB'):
        return 'VB'
    elif token.tag_.startswith('NN') or token.tag_ == 'DT':
        return 'NN'
    else:
        return token.tag_
    
def is_noun_chunk(token):
    for nc in token.doc.noun_chunks:
        if token.i in range(nc.start, nc.end):
            return True, nc.end
    return False, token.i + 1

def get_ptn(token):
    line = token.doc
    
    ptns = [ptn_transform(token)]
    if token.i+1 < len(line):
        is_NC, next_start = is_noun_chunk(line[token.i+1])
        ptns.append('NN' if is_NC else ptn_transform(line[token.i+1]))
        
        if next_start < len(line):
            is_NC, _ = is_noun_chunk(line[next_start])
            ptns.append('NN' if is_NC else ptn_transform(line[next_start]))
    return ' '.join(ptns)

# %%
patterns, ngrams = defaultdict(Counter), Counter()
sents = defaultdict(lambda: [])
 
WINDOW_SIZE = 3
for line in remains:
    for token in line:       
        # if token.lemma_ == 'discuss' and is_past_passive(token):
        if token.lemma_ == 'discuss':
            ptn = get_ptn(token)
            ngram = ' '.join([tk.text for tk in line[token.i : token.i + WINDOW_SIZE]]) # discuss _ _
            # ptn = ' '.join([ptn_transform(tk) for tk in line[token.i : token.i + WINDOW_SIZE]]) # VB _ _

            
            ngrams[ngram] += 1
            patterns[is_past_passive(token)][ptn] += 1
            sents[ptn].append(line.text)

# %%
high_ngrams = get_high_freq(ngrams)
high_ptns[True] = get_high_freq(patterns[True])
high_ptns[False] = get_high_freq(patterns[False])
sort_dict(high_ptns[False]) # 這裡的 VBN 為完成式
# Out:
# Total: 10754, Avg: 1.8332765086941698, Std: 7.727115221942229
# Total: 2606, Avg: 11.136752136752136, Std: 54.50035771589748
# Total: 8148, Avg: 16.975, Std: 81.10633067153266
# [('VB NN of', 1209),
#  ('VB NN .', 803),
#  ('VB NN with', 615),
#  ('VB NN CC', 426),
#  ('VB NN ,', 389),
#  ('VB NN in', 337),
#  ('VB NN NN', 234),
#  ('VB NN RB', 227),
#  ('VB with NN', 222),
#  ('VB NN for', 189),
#  ('VBN in NN', 152),
#  ('VB .', 132),
#  ('VB NN VB', 127),
#  ('VB WRB NN', 97),
#  ('VB NN WDT', 96),
#  ('VBN NN of', 87),
#  ('VB NN at', 83),
#  ('VB NN on', 83),
#  ('VBN NN with', 75),
#  ('VBN RB .', 75),
#  ('VB CC VB', 73),
#  ('VB NN TO', 71),
#  ('VBN .', 69),
#  ('VB NN to', 67),
#  ('VB in NN', 65),
#  ('VB NN JJ', 52),
#  ('VBN RB ,', 50),
#  ('VBN by NN', 50),
#  ('VB VB NN', 49),
#  ('VB NN VBN', 47),
#  ('VB NN :', 43),
#  ('VBN with NN', 42),
#  ('VB NN RBR', 41),
#  ('VB NN between', 39),
#  ('VB NN from', 35),
#  ('VB NN as', 32),
#  ('VB `` NN', 31),
#  ('VB NN MD', 30),
#  ('VB RB .', 29),
#  ('VB , NN', 28),
#  ("VB . ''", 27),
#  ('VB whether NN', 27),
#  ('VB RB NN', 27),
#  ('VB NN that', 26),
#  ('VBN , NN', 26),
#  ('VBN NN CC', 26),
#  ('VB NN CD', 25),
#  ('VBN NN ,', 25),
#  ('VB NN', 25),
#  ('VB , CC', 24),
#  ('VBN NN in', 22),
#  ('VB WRB TO', 22),
#  ('VB at NN', 21),
#  ('VB RB ,', 19),
#  ('VB NN about', 18),
#  ('VBN at NN', 18),
#  ('VBN NN .', 18),
#  ('VBN NN RB', 17),
#  ("VB NN ''", 17),
#  ('VB NN -LRB-', 17),
#  ('VB NN by', 17),
#  ('VBN RB VB', 17)]

# %%
sents['VB NN TO']
# Out:
# ["the 39 signatories will be discussing what to do about pressures for development of the continent 's resources .",
#  'this emerged yesterday the two companies finally they were discussing a deal to thwart the us car , which intends to build a 15 per cent in jaguar in preparation for a full bid .',
#  ", america 's third largest car maker , and mitsubishi of japan are discussing plans to set up vehicle manufacturing plants in europe .",
#  "with johnsonian vigour , eliot discussed the way to run a society ; he surveyed with distanced irony `` the literature of fascism `` , also printing macdiarmid 's `` second hymn to lenin ' .",
#  'mr poole said national leaders would meet on thursday to discuss ways to intensify pressure on health service managers to re-open talks .',
#  'he has set himself the task of trying to discuss the agenda to develop the next two decades on issues such as training , education and poverty .',
#  'president alan of peru for a planned summit on february 15 with president bush to discuss drugs to be `` deferred `` because of the invasion .',
#  'cill , after causing the battle of the books , came back to tara for the convention of at the hill of synod , where they discussed what to do about poets .',
#  'nonetheless , papers such as the daily mail have been prominent in articles and letters about mental handicap , and in particular in discussing the right to live issue .',
#  'clustered in the corner of an airless photographic studio , five worried mothers are discussing what to give their children for dinner .',
#  "`` at marriage guidance , `` went on henry , `` i did n't feel able to discuss my need to tie you to the bed and whip you with my pyjama cord .",
#  'like all summaries , this average d makes sense if the coefficients being averaged are broadly similar ; we shall discuss what to do if they are not in section 13.6 .',
#  'in this chapter we will examine what these statistics and discuss the extent to which they provide an accurate picture of the range and extent of criminal behaviour .',
#  'discuss the extent to which females are judged by looks rather than ability .',
#  'browse the range on show in the craftworkers studios , or maybe discuss one-off pieces to suit your special wishes .',
#  'this week , the nations of western europe met in paris to discuss a new organisation to run meteorological satellites .',
#  'when you have noted every single thing which you wish to discuss the information to prepare a well-ordered list of questions to take in with you .',
#  'if you perceive this could be a problem perhaps the two of you could discuss a contingency to deal with this .',
#  'yvonne spirited me back to her office and we held a quick post-mortem , agreeing the evening had been a roaring success and discussing ways to improve our performance .',
#  'the dutch were discussing plans to evacuate their nationals bernard callinan had a dinner one night at their headquarters .',
#  'mr tarry said he had devoted a lot of time going to meetings and discussing what to do next .',
#  "officials at the football association are meeting today to discuss what to take pitch invasions during colchester united 's match with cardiff city at layer road on friday night .",
#  "penny hughes , president of coca-cola in britain and ireland , said : `` our interest in football is very wide and very broad so obviously we 're always discussing any other opportunities to further increase that relationship .",
#  "yet the board on may 27th to discuss a new trading system to replace the ageing seaq system , its members were conscious of the exchange 's troubles , not its successes .",
#  'this week he met environment tony to discuss government proposals to give local authorities greater powers to curb illegal camping .',
#  'several aspects of the social circumstances of older people are important when discussing their ability to pay for the care they require .',
#  'initially she discussed her desire to go to the funeral with her husband .',
#  'we can for instance , endlessly discuss the need to maintain and reinforce brands , now that the service promise bound up with them has become so important .',
#  'the group discussed the extent to which training was related to jobs .',
#  "before we do the role i 'd like to discuss them to sort of , so we know exactly what we 're gon na do .",
#  'then i will proceed to discuss the extent to which lakatos and kuhn can legitimately be characterized as rationalists or relativists .',
#  'had long conversations with him in paris and london , in which they discussed choices to be made , goals to be pursued , and the practical and moral aspects of their work .',
#  'a further round of talks is due in mogadishu later in february to conclude the ceasefire , and to discuss the means to achieve national reconciliation .',
#  "supply days , when at least in theory the commons discussed ministerial proposals to spend money , have been replaced with opposition days which allow the government 's opponents to decide the subject for debate .",
#  'alice thought it a wonderful gesture , and for the remainder of the journey they discussed their joint to make will and martha pritchett financially secure for the rest of their lives .',
#  "in august 1934 the soviet writers ' congress in moscow provided a unique forum at which communists and non-communists could discuss positive measures to promote an anti-fascist cultural front .",
#  'susan clements borrows it for discussing some issues to do with drug and alcohol teams .',
#  "our speaker , william lorimer , director of furniture for christie 's , st. james 's , will discuss what to look for when buying furniture .",
#  'and fiona were discussing their plans to visit top shop in their lunch break .',
#  'if you wish to discuss anything to do with the protection of inventions , designs , copyright or trademarks , please contact him beforehand at',
#  'a second principle is sometimes discussing the extent to which unequal people should be treated unequally .',
#  "a special meeting of the city council 's technical services committee has been called for monday to discuss a plan to sell the clinical incinerator plant at .",
#  'while behind-the-scenes the americans were discussing remarks to have been said by gary player .',
#  "the security forces had been sent to the bank to escort naim to a meeting with to discuss the bank 's refusal to advance money to pay for a contract to print 1 , 000 , 000 passports .",
#  'government ministers from 112 countries in london on april 9-11 to co-ordinate efforts to reduce the demand for illicit drugs and to discuss measures to curb and the illegal flow of cocaine .',
#  'the entry of iraqi soldiers into diplomatic premises in kuwait on sept. 13 and 14 , and `` aggressive acts `` against diplomats , and to discuss measures to tighten the embargo on iraq .',
#  'at the height of the violence mandela and de klerk had meetings to discuss measures to quell the fighting .',
#  "p & eacute ; rez de cu & eacute ; llar 's report proposed a conference of all the 164 signatories to the fourth geneva convention of 1949 - including israel - to discuss measures to protect palestinians in the occupied territories .",
#  'a videotape made by the had been broadcast on jan. 25 , purporting to show at a private meeting boasting croatian arms from hungary , and discussing plans to kill officers .',
#  'the memorandum went on to discuss a rally to be held in durban in march 1990 at which buthelezi would urge the lifting of sanctions and president de klerk .',
#  "bulgaria 's foreign affairs stoyan ganev met his counterpart antonis samaras in athens on jan. 11 to discuss bulgaria 's intention to recognize the breakaway yugoslav republic of macedonia .",
#  '`` we are simply here to discuss what measures to take in the light of recent developments .',
#  'this report offered a useful opportunity to discuss the extent to which the age factor might influence clinical decision .',
#  'the groups discussed the need to timetable for the additional assessment , difficulties in applying criteria , and the need for considerable staff development in the area of integrated delivery and assessment .',
#  'of the catering recruitment company discusses ways to get the best out of recruitment companies while warning of the pitfalls which can occur if the proper communication channels are not established .',
#  "we could thus highlight the problems faced by each system , and discuss the extent to which each system 's approach was influenced by its architecture .",
#  'discuss qualities to do it well - stealth , , pretending to look at someone other than your `` prey `` .',
#  'this assumption will be examined in detail in chapter 3 , as it is so pervasive and , and re must be able to discuss the degree to which its basis is faulty .',
#  'meanwhile , the high street bank has been discussing plans to log untouched jungle with edinburgh forestry consultancy , and timber services .',
#  'councillors are meeting now to discuss proposals to build a coca cola schweppes distribution centre in northampton .',
#  "the council 's development sub-committee will discuss an application to remove the statue next week .",
#  "all regimental organisations and groups in the area are invited to a meeting in the town 's club tomorrow to discuss a proposal to set up a confederation of ex-service organisations .",
#  'members will also discuss questions to be put to candidates during the general election campaign .',
#  "the group also discussed a plan to make a trip to york to see a needlework exhibition which will feature the duchess of york 's wedding dress .",
#  'the latest sighting of hamilton-jones at the kelvin hall prompted ward to report yesterday senior officials would meet quickly to discuss methods to prevent him from .',
#  'the two leaders were also discussing the american plans to deliver humanitarian aid by air to bosnia , which britain has welcomed but declined to join .',
#  'yesterday it was played at a meeting of wildlife agencies called in kirkwall to discuss the best way to move the whales out of scapa flow .',
#  'discuss the extent to which the cyclical fluctuations in question ( 3 ) may be a result of : ( a ) monetary variables ; ( b ) random disturbances .',
#  "they 're holding an emergency tonight to discuss a plan to build up to 2 , 000 homes there .",
#  "the new-look health authority has been meeting to discuss the nuffield 's application to become self-governing .",
#  "meanwhile , in south africa , mr de klerk held talks with the african national congress to discuss the a n c 's decision to suspend its armed struggle ."]

# %%
total, correct = 0, 0
for line, is_correct in rights[:500]+wrongs[:500]:
    for token in line:
        # if token.lemma_ == 'discuss' and is_past_passive(token):
        if token.lemma_ == 'discuss':
            ptn = get_ptn(token)
            # ngram = ' '.join([tk.text for tk in line[token.i : token.i + WINDOW_SIZE]]) # discuss _ _
            # ptn = ' '.join([ptn_transform(tk) for tk in line[token.i : token.i + WINDOW_SIZE]]) # VB _ _

            if (ptn in high_ptns[is_past_passive(token)]) == is_correct:
                correct += 1
            else:
                print(ptn in high_ptns, line)
            total += 1

print(correct/total)
# Out:
# False your family should discuss about my suggestion and we should find a date for a meeting in your favourite objects .
# False i m writing to discuss about the cards that we are selling .
# False isabella discusses that she loves john with her boyfriend because she does n't want to marry him .
# False the story of the adjustment bureau discusses on whether we can control our fate or some invisible power controls us .
# False maybe we could use this time to discuss about the project if you want .
# False word limit if you want to discuss more about the conditions for this permission , you would contact me by e - mail or telephone # # # # -####.
# False as discussed i will be at your department building at 11 am next monday .
# False we discussed for a long time and our consensus seems to be that the best option is to make ads with an important actor .
# False we 'll have enough time to discuss some issues after dinner .
# False this topic is too important to discuss , once we live in a free society and we have to respect the choices which each one chooses .
# False plot : questions about women situations beauvoir discussed about every quotidian situations to involve men and women .
# False i think we could book another lunch in some other place of your preference where we can discuss about our business and forget this unfortunate incident .
# False if possible , we would like a meeting again , in a better place , to discuss more about business .
# False like every day she was on her way to work , when she heard a couple discussing about pollution , in front of their car , while its engine was still running and the stereo still playing .
# False i do n't know anything about the famous persons and i think to spend time discussing about these stupid things is a waste of time .
# False we could take the opportunity to discuss better the services our company want to offer to you .
# False i want to meet you to discuss more about the planning in detail and i would be very happy to be a part of your great work for conservation of wild animals .
# False it discusses about building and rebuilding problems .
# False so , let 's discuss from the begining , .......
# False maybe we should have a page about your products , testimonial from your satisfied customers , tracking of the clients orders we should make an appointment to discuss about these points more deeply .
# False i do n't think it 's interesting to discuss if gavin is getting a divorce or not .
# False she can spend 30 minutes discussing some small business issues that could be to discuss for 5 minutes .
# False it would be a great opportunity to spend some time away from work and discuss while our wives meet eventually .
# False i often contact with italy technician discuss about the profession skill and i like italian , because they have talent and so smart , i talk to them then i can learn more about profession knowledge .
# False i participated in an it congress to discuss about the best practices to manage it .
# False i sometimes have meetings and go on business trips . i often have holidays . i talk on the phone and write emails . i often meet my business partner and we discuss about work .
# False the second invention discussed earlier is a perfect example of a service robot used for medical purposes .
# False so , next week we need to discuss about it and i think that you have to do more tasks .
# False you could come to me to discuss if you have other opinions or different thoughts .
# False please give me an answer and a date for an appointment for discuss about a plan .
# False we have discussed about who should be in our ads and we reached the consensus in using actors/ actresses from the soap opera instead .
# False i appreciate it if we could discuss about our transaction .
# False i have had a meeting with my team and discussed after this brainstorm , i have chosen third picture and slogan .
# False i always have a meeting to discuss about the development plan .
# False i would like to meet you in person in order to discuss further about my thoughts .
# False well , i think it 's all too complicated to discuss , because it comes to public will , .
# False the main points we have to change are : fix the bathrooms ( i even have found a sponsor ) , get new desks , maybe get some old tables for some rooms from the old cafeteria , so we have more space to work at the breaks , find a good balance on the field trips between money and glamour - it is more about what we can learn and not how fancy it was - and the rest we will discuss later in person .
# True during this afternoon , we are going to discuss , play games , listen to music , dance ...
# False the fourth stage of my plan is to join in a scientific group to make friends and discuss about science .
# False roland visited me yesterday in my office to discuss about our company's new policy .
# False fashion is not a big deal , it 's only practice , wisdom and awareness ... let 's discuss much about fashion , because fashion is torn between colors and trends , having a good mood , playing with what we have in cupboard , or vintage pieces , is the best exercise of their own style , without having to buy pet peeve of the ankle boot , that everyone has , or the bag that all your friends use , trend is a range of options and is currently increasingly a lot .
# False this makes me feel uncomfortable in situations where we have to discuss about the development of our department .
# False plot : they were discussing about the stock market , fund and economic moment in the future .
# False i do n't like to discuss about the life of artists , especially the artist i like more .
# False i hope not only to improve my listening skills , but also the speaking skills so that i can discuss other more unrelated to the work stuff with customer for future easier business .
# False with that in mind , i would like to suggest to arrange a meeting with jed to discuss those problems next wednesday 13th may , before the situation deteriorates more .
# False hello anna , after we discussed about your different future ideas last time , i found this zookeeper ad in the newspaper .
# False we must discuss about hiring new staff , paying the overtime and offering some bonuses and incentives to re-motivate the team .
# False with my staff we have discussed for a long time about who can convice our client to buy our best product .
# False first of all , we discussed to moving from the world class sports , like athletics , and go to a different kind of sports , like wrestling .
# False i 'm writing to you in order to discuss about your fear of confined spaces .
# False so we need to discuss about the situations before it gets worst .
# False if it 's possible , could we meet next week and discuss about the details of our contract ?
# False we discussed internally about the result and came to a conclusion that our present logo is very old fashioned , up to date .
# False have a good day anna , and keep in touch to discuss about this later .
# False besides , sally is looking forward in meeting us again to discussing about the future .
# False however , we need to discuss more on two requirements with you .
# False 6-listen to all opinions and discussed especially with young members and encourage them to put more ideas .
# False we used to discuss a lot because of the car " schedule " or how much each one had to pay for car maintenance .
# False we were discussing about some changes for the company for the next year and then he proposed to our director a new structure in his department .
# False first : we discussed about new hires and what we need to do to get this ; second : cut jobs .
# False at our next meeting we will discuss about this .
# False we discussed if we have to renew it with the old company or do a market research .
# False we discussed so much , but after two hours everyone had his own idea .
# False we had the meeting to discuss about a new project in the stamping , but it was bad .
# False the strategies we discussed should speed up production without increasing our costs .
# False in the first year of school , we discussed about different things and in the second year , we became enemies .
# False i guess these people liked it too , the exchanges about countries , languages , jobs , sports , a lot of subjects were discussed about .
# False several ideas were discussed and finally we came to a final agreement .
# False for example , the talk show was funny , but sometimes the topics they discuss is not suitable for children because , there are too much sex and violence in their conversation .
# False it 's an it job , so i stay at my computer all day , usually i meet my clients at my desk to discuss about the software solutions that i develop .
# False she really wants to see you to discuss of all this new opportunities with you during a meeting .
# False when i was young and had to meet some friends , all details had to be discussed before because once we had left home there was no cell phone to get in touch .
# False many ideas were discussed , probably the best was the company distributing fast food .
# False i am proposing we should meet and discuss about my proposal to find a better solution .
# False today i saw the pope conduct a ceremony and he discussed about the conflict in ukraine .
# True isabella discusses with her boyfriend because she do n't want to marry him .
# True the story of the adjustment bureau discusses whether we can control our fate or some invisible power control us .
# True now we can read some news , look some shows , discuss it , but we should n't believe at all of this information .
# True in my opinion , we may discuss following solutions :
# True together with the school principal i already discussed first steps to support poorer student , to renovate school rooms and to improve the cafeteria performance .
# True anyway , i hope to contact me to discuss with this issue , and reach to good deal .
# True now almost all people have been discussing and concerning the case .
# True let 's meet and discuss nearest plans .
# True the company has a salary plan which will discuss in appropriate time .
# True i would like to discuss with you , jed and me tomorrow afternoon .
# True item 2 : the manager assign to the tasks to achieve the job which are : a ) shary contact alson to ask her about the requirements for the next meeting , b ) alex , with his team , must brainstorm some new ideas to discuss it next meeting , c ) booking a table at a malaysian restaurant as one of the office party on the end of this month .
# True i will discuss length of coffee break because most of you said that now time for break is not enough .
# True we stopped to discuss situation .
# True the price open to discuss is 300 euros and you can join me on my mobile phone on the evening .
# True sometimes i have meetings with other colleagues and we can discuss very special problems .
# True i was wondering if you could meet me next week to discussing condition of the deal .
# True roland visited me yesterday in my office to discuss our new company policy .
# True plot : they were discussing the stock market , fund and economic moment in the future .
# True would you like to discuss with me on the contract the next week ?
# True if you would like to discuss with me , you can contact me at xxx@jostjoined.com .
# True if you want to discuss with me , please contact me at # # # # # # # # # # .
# True there is a good information on that survey that we can discuss it later .
# True tomorrow , at the morning i will meet the ceo of the company to discuss with him about our project .
# True we need to held board of directors meeting as soon as possible to discuss design team's issues .
# True hello everyone , how's going these days ? i would like to hole a conference with the board of directors about discussing problems of jed 's team .
# True i can discuss with you .
# True hi bill , per our research and discuss then our team suggest to start using tv start who are in soap opera , as they are often in public eyes .
# True if you would like to discuss with me , you can contact me at # # # # # # # # # # # or email me.%% i look forward to hearing from you .
# True i liked the music because he talks about some important issues , using simple ways and a soft way to discuss it .
# True so they discussed with each other for a few minutes and said that the deal was canceled .
# True her family is very rich and for them accept this situation she must discuss with them .
# True 6-listen to all opinions and discussed , especially young members and encourage them to put more ideas .
# True first : we discussed new hires and what we need to do to get this ; second : cut jobs .
# True after many discussing , we 've decided to produce fewer items , like donuts and cookies of many flavors , and that made the costs decreasing .
# True we had the meeting to discuss a new project in the stamping , but it was bad .
# True to next week , i suggest a meeting to discuss with more details about the move our company and also talk about your concerns .
# True we discussed future of modernization telephone network our company and received answer about all our questions and complexity .
# True we plan to mail the material to you on july 15th , alternatively you could visit our headquarters after july 15 to discuss then .
# True if you interesting our offer we could meet at the lunch and discuss our deal.%%
# True when we want to discuss this issues , the receptionist jeered us .
# True i think the presentation would have been better if we had been able to discuss it .
# True first all the purpose of the meeting was discuss budget of the next year .
# True i discuss with the collaborator for create and implement a produce process , and her followed for improve that .
# True they not discuss the problems .
# True one thing is good in the television , the novels , because of the themes discussed it that are of social kind troubles .
# True i believe the layoffs the staff who had been hired a last year another option could be cut expenses like cell phone and electricity maybe we will discuss in the next meeting .
# True after it i would like to discuss with you , there about .
# True i want to discuss you some of the important topic , so come to my house.%% see you !
# True in our next meeting , let 's discuss pros and cons of my proposal .
# True anyway , we discussed what to cook and how to prepare .
# True but in this meeting we will discuss advantages and disadvantages .
# True hi ian , everybody discusses you decision to resign from stowark bank .
# True one last thing that i got ta tell you , they want to met us next month to discuss a new contracts in the future .
# True i started to discussed with this guy who is my husband now .
# True seriously , i propose for first discussing how to do for recovering the trust of our clients and how to recover too , our former famous excellence .
# True tomorrow i will fly to oslo to meet uk marketing team to discuss sales plan for the next half year .
# True i had discussed with my colleague of team .
# True title : tuesday with morrie author : mikey type of story : true story setting : america , 1994 main characters : the author and professor morrie plot : professor morrie is fall ill but date with his student mikey to discuss the life .
# True she would like to discuss with that later .
# True the board of directors decided to do an emergency meeting , and then they discussed about two solutions .
# True i 'd like to discuss that with you .
# True hi , i 'm mohammed abdul rahim al subhi i am 16 , and studying at the secondary level i have a problem and i want to i will discuss quickly i do not understand most of the words do you have a solution!%% ! ! ! ! !
# True we check the car and try to discuss with the owner , it was not so easy the owner want her price and i has n't enough money .
# True the second we discussed is the deadline for the activities we have to design .
# True i have coursed social communication at early 2000 ' s , and i remember we used to discuss a lot about the impacts of media changing in the world .
# True try to discuss the things with your boss to find a ideal order and priority .
# True also , my job request helps the company customers giving a support and often have meetings to discuss systems plan .
# True we can discuss about some points : 1st : a leader must be a confident man ( or woman ) and must conduce they team the more save as possible during the tasks .
# True in brazil , the difference between genders is a relevant topic that it 's been discussed in a long time .
# True giulia asked about new products and we discussed this point .
# True at that time we will discuss with our new policy more in detail .
# True to discuss in the next meeting !
# True most people work 45 hours a week , give or take , we are all good partner , and we spend more time to discuss production process issue and advise solutions , we also have managers , one is young and relaxed , the other is a little bit older and is stressed out .
# True i think we must make a group meetings to discuss all these things , because the opinion of my team is very important for me and i ca n't decide anything before discussing with them .
# True i think we must make a group meetings to discuss all these things , because the opinion of my team is very important for me and i ca n't decide anything before discussing with them .
# True we have arranged a meeting next week where we could discuss details .
# True there are over 20 professional team from all around the would , those who are doing the research in the bio - chip industry , and the main gist we discuss is the issue about improving efficiency of micro- channel in nano - scale development .
# True so , we need to discuss all the advantages and disadvantages of the move .
# True i think the gasoline price and pollution increase so that water and air quality will be low so the world leader must discuss electric cars idea .
# True we need to discuss when i got to office , and we need to be hurry .
# True they discussed a long time but they do n't find a solution .
# True please know , you can always call me , if you like to discuss .
# True i have spent a month attending a university 's course in the u.k. so i am going to discuss similarities and differences between the university i have attended in the u.k. and the university of rome .
# True dear akira , my lover , i would like to discuss with you about my career path .
# True mazer said that he got one issue about pfu , and he will discuss with supplier first to make sure what the problem is and find out the root cause as soon as possible .
# True i suggest we need have a meeting to discuss .
# True i suggest that we make a meeting to discuss .
# True this zone has meeting in the year to discuss the economic , the society and other important issues to latin america countries .
# True we discussed an interesting book which we had read and the movies which we had watched .
# True during this meeting we discussed 3 different things , and we discussed in 2 steps .
# True during this meeting we discussed 3 different things , and we discussed in 2 steps .
# True now he start making plans and discuss with me everyday .
# True last thing is must have a meeting every day to discuss settlement progress of previous issues and new issues encountered current day .
# True then we reviewed the items on the agenda and we started to discuss first item .
# True the group discussed any problem with the goal to find a solution .
# True we discussed the our future , and he told me that his specialists predicted that the profits of his firm will be increase in next year , therefore , he can to increase their purchases from us by 20 % .
# True sometimes , we go out for dinner on weekend , and discuss lots of topic not only at work , i really like them .
# True in addition , i asked him to discuss with you those features .
# True we discuss many things .
# True sally would like to met us again soon , for discuss news ideas and future projects .
# True then one other chapter we can start to discuss , it concerns research .
# True when i had problem , i was discussing with her to get the right decision .
# True our partners from usa want to discuss deals detail .
# True differing opinions about robots our magazine interviewed three specialists about robots , in order to discuss differents points of view of this so important subject .
# True hi mike , here is the topics that were discussed on the last meeting about making more investments in business intelligence technology .
# True the purchasing manager compared several brands , and he discussed with the boss for several times .
# True hoping you can follow my thoughts and we can discuss face to face soon .
# True in our meeting we discussed about three topics .
# True we have to discuss in a shorter group and to find a solution as soon as possible .
# True give me a call tomorrow afternoon to discuss next steps .
# True he said that he would send me a e - mail to we discuss with more details .
# True to : xxx@hotmail.com from : xxx@hotmail.com subject : discuss the preparation of teachers for the new year dear principal , this is discuss the preparation of teachers for the new year : - distribution course schedule for the new year .
# True to : xxx@hotmail.com from : xxx@hotmail.com subject : discuss the preparation of teachers for the new year dear principal , this is discuss the preparation of teachers for the new year : - distribution course schedule for the new year .
# True some days later , we were discussing the payment's way and signing the contract .
# True i propose that we discuss pros and cons .
# True if you ask me , to my mind it 's relatively difficult to discuss the topic .
# True we plan to mail the special materials to you in next month and you could visit our shop after that to discuss with us .
# True so , we have to be very attentive to what children see and we have to discuss with them about it .
# True we discussed approximitly 30 minutes about our plans .
# True the coo disagreed that they should n't move too quickly , and he propose they should schedule another meeting with the stars company ceo , next monday to discuss another points about the proposal , but the cfo insisted that is better to wait the result , to avoid creating false expectations in the company .
# True gender equality is a topic which is discussed in all over the world . and also in germany where i live .
# True to xxx@free.fr , xxx@orang.fr , xxx@free.fr , xxx@talktalk.com from xxx@orange.fr subject : preparation general meeting on november 17th dear colleagues as discussed his morning in our telephone conversation , i 'm writing to summarize the yesterday 's briefing for the agenda of the next general meeting on november 17th , 2013 .
# True on the agenda they have to discuss about 5 items .
# True meeting minutes for hire new a ict manager there is a interesting meeting hold today morning to discuss the topic that hire a new ict manager . some of decisions were made .
# True at the beginning of the meeting , my boss asked if we had agenda , and then he started discuss new two contracts .
# True then we discussed second contract , but we did n't get in same page .
# True the objective of the meeting to plan for ceremony of our department employee 's service award , during the meeting we discussed task for each member of the group .
# True so t he manager took this subject to discuss with the director .
# True the main purpose of this meeting was discuss the latest claims from the customer about the project .
# True the follow point to be discussed was the delays on the time plan .
# True the goal of the meeting was to discuss merger of two companies .
# True we have to make a jump in our products , but when we discussed a pros and cons for this proposal , we found a big con is that we must pay a lot of money to have new technologies , but the advantage is so obvious , we can sell more products to new customers , and to make our customers satisfied .
# True we were at the end of the junior staff officer course and part of the final exam was a presentation stage , aiming at discussing the final essay .
# True i saw 10th boss of better italian restaurants and they discussed the new international menu 2014 , for consolidate the name of italian 's food in the world .
# True the marketing chief wanted to enhance the burn fat topic , but the sales manager disagree about that , because this matter was discussed just in the previous number .
# True as a next step , we discussed a company report for the last quarter .
# True in this case , is not polite discussing polemics issues like : politics , religion , etc .
# True today , he went lawer to apply divorce and i had discussion with him and explained that discuss with his wife and clarify the problem , but he did n't listen .
# True the purpose of this meeting was to discuss club charter .
# True we have a dinner , talk about day and say stories , discuss a problems , trying to find a decisions .
# True i believe that world leaders need to meet and discuss this for to implement the use of renewable energy .
# True i know that some people will have some concerns but we 'll discuss tomorrow .
# True after he had introduced an action plan , he distributed tasks to me and my colleagues and told us that he 's going to call another meeting for discussing next steps .
# True i and satoshi loved japanese baseball , so we discussed about a lot of thing that we loved team .
# True the meeting started with the manager discussing company 's problems .
# True she was aware of major problems and tried to discuss with david ... todd said that in case of a merger , we do n't need 2 cio .
# True on my first day in new company , the president was talk with me to discuss and talk about my career and great opportunities on the future .
# True we can discuss this two ideas in our next meeting .
# True he asked to schedule another meeting to discuss team 's integration in details .
# True discussing missing person , that is simply gossip , is unacceptable.%% it is inadmissible to speak about relatives , in particular to discuss husbands .
# True discussing missing person , that is simply gossip , is unacceptable.%% it is inadmissible to speak about relatives , in particular to discuss husbands .
# True as you know , we had meeting with mo company to discuss a technical infrastructure for our company .
# True it was good meeting we discuss this points : - server room .
# True mr. chang and i enjoy discussing any questions about management of hospital together .
# True i discuss order with my clients in the dinner hall .
# True we discussed gxc solutions and review the past year .
# True all together decided the targets and discuss strategy .
# True the first point was discussed on the meeting was the charges of the each sector , thus the quality manager takes your responsibility of a new product when it is introduced on assembly line .
# True after football match a lot of people discuss each other during the week .
# True 3- the marketing director should organize a meeting with the government officer within one week to discuss new terms of the contract .
# True the issues which were discussed on this lesson are very helpful and inspirational subjects .
# True we have been work hard , however , we do n't feel much stress because we are very frequently discussing how we can achieve the goals .
# True i will contact you in a couple of weeks to discuss depply in dtails about the launch party we would like to schedule .
# True in today 's meeting , we discussed new services to be provided by the firm .
# True therefore , they were discussing the candidate .
# True we were always discussing lesson together .
# True i think we should discuss with document and it department first and than narrow down our project process .
# True gm agreed about it and scheduled another meeting on next friday for discussing detail .
# True we had met in our department in last week , we discussed problem with new study plans for students on second course .
# True finally we discussed new financial position .
# True dear sarah .. we ha ve meeting today and they discuss t wo points .
# True they all agreed that it required another meeting to discuss budget issue .
# True after discussing studies interesting , i have got their cards .
# True dear mr. smith , i was surprised about items of an agenda which were discussed on our meeting 2 hours ago .
# True at the beginning of the meeting , the ceo was discussing about their relationship with sunset company , the first item of the agenda said that the sunset 's ceo has resigned , the second item is that there is a meeting in sunset company next monday , and the last item is discussing the problems with the sunset company .
# True i 'll arrange the meeting on next monday to discuss results with you .
# True we have to discuss with them all points , tell them all the pros .
# True we discussed the several ways for transportation their goods .
# True work - life balance is discussed in these days , so we will take vacations more easily in near the future .
# True i believe that finance should be more discussed on school .
# True feel free to discuss with about this matter .
# True we spent most of the time discussing the future work .
# True i suggest that if anyone has any concern , regarding my proposal , email me or we meet and discuss at our next meeting .
# True he discussed our most important points in detail , in the body of this presentation .
# True a scientists will be popular , they will can discuss a problems with ecology .
# True 2 - we discussed about many important marketing topics .
# True we discussed about many themes , she is adorable and very smart !
# 0.6857825567502986

# %%
test =  nlp('we discussed about many themes , she is adorable and very smart !')
print(list(test.noun_chunks))
for tk in test:
    if tk.lemma_ == 'discuss':
        ptn = get_ptn(tk)
        print(ptn)
        print(ptn in high_ptns[is_past_passive(tk)])
high_ptns[False]
# Out:
# [we, about many themes, she]
# VB NN ,
# True
# {'VB , CC': 24,
#  'VB , NN': 28,
#  'VB .': 132,
#  "VB . ''": 27,
#  'VB CC VB': 73,
#  'VB NN': 25,
#  "VB NN ''": 17,
#  'VB NN ,': 389,
#  'VB NN -LRB-': 17,
#  'VB NN .': 803,
#  'VB NN :': 43,
#  'VB NN CC': 426,
#  'VB NN CD': 25,
#  'VB NN JJ': 52,
#  'VB NN MD': 30,
#  'VB NN NN': 234,
#  'VB NN RB': 227,
#  'VB NN RBR': 41,
#  'VB NN TO': 71,
#  'VB NN VB': 127,
#  'VB NN VBN': 47,
#  'VB NN WDT': 96,
#  'VB NN about': 18,
#  'VB NN as': 32,
#  'VB NN at': 83,
#  'VB NN between': 39,
#  'VB NN by': 17,
#  'VB NN for': 189,
#  'VB NN from': 35,
#  'VB NN in': 337,
#  'VB NN of': 1209,
#  'VB NN on': 83,
#  'VB NN that': 26,
#  'VB NN to': 67,
#  'VB NN with': 615,
#  'VB RB ,': 19,
#  'VB RB .': 29,
#  'VB RB NN': 27,
#  'VB VB NN': 49,
#  'VB WRB NN': 97,
#  'VB WRB TO': 22,
#  'VB `` NN': 31,
#  'VB at NN': 21,
#  'VB in NN': 65,
#  'VB whether NN': 27,
#  'VB with NN': 222,
#  'VBN , NN': 26,
#  'VBN .': 69,
#  'VBN NN ,': 25,
#  'VBN NN .': 18,
#  'VBN NN CC': 26,
#  'VBN NN RB': 17,
#  'VBN NN in': 22,
#  'VBN NN of': 87,
#  'VBN NN with': 75,
#  'VBN RB ,': 50,
#  'VBN RB .': 75,
#  'VBN RB VB': 17,
#  'VBN at NN': 18,
#  'VBN by NN': 50,
#  'VBN in NN': 152,
#  'VBN with NN': 42}

# %%
line = 'this zone has meeting in the year to discuss the economic , the society and other important issues to latin america countries .'
tokens = nlp(line)

# %%
for nc in tokens.noun_chunks:
    print(nc)
# Out:
# this zone
# the year
# the society
# other important issues
# latin america countries

# %%
explacy.print_parse_info(nlp, 'we discussed about many themes , she is adorable and very smart !')
# Out:
# Dep tree           Token   Dep type Lemma   Tag Part of Sp
# ────────────────── ─────── ──────── ─────── ─── ──────────
#               ┌──> i       nsubj    i       PRP PRON
#               │┌─> m       npadvmod m       XX  X
# ┌┬────────────┴┴── writing ROOT     write   VBG VERB
# ││             ┌─> to      aux      to      TO  PART
# │└─>┌──────────┴── discuss advcl    discuss VB  VERB
# │   └─>┌────────── about   prep     about   IN  ADP
# │      │       ┌─> the     det      the     DT  DET
# │      └─>┌────┴── cards   pobj     card    NNS NOUN
# │         │  ┌───> that    dobj     that    WDT ADJ
# │         │  │┌──> we      nsubj    -PRON-  PRP PRON
# │         │  ││┌─> are     aux      be      VBP VERB
# │         └─>└┴┴── selling relcl    sell    VBG VERB
# └────────────────> .       punct    .       .   PUNCT
