# %%
from collections import defaultdict, Counter
from tqdm import tqdm
import gzip

# %%
class DotDict(dict):
    def __getattr__(self, name):
        return self[name]
    
def parse(block):
    lines = [line for line in block.split('\n') if line]
    parsed = [ DotDict() for _ in range(len(lines)) ]

    for i, line in enumerate(lines):
        index, token, lemma, dep, pos, tag, head, children = line.split('\t')

        parsed[i].update({
            'i': int(index),
            'text': token,
            'lemma': lemma,
            'dep': dep,
            'pos': pos,
            'tag': tag,
            'head': parsed[int(head)],
            'children': [parsed[int(ch)] for ch in children.split(',') if ch],
            'doc': parsed
        })
        
    return parsed

# %%
block = '''0	through	through	ROOT	IN	ADP	0	5,6
1	infected	infected	amod	JJ	ADJ	5	
2	blood	blood	nmod	NN	NOUN	5	3,4
3	or	or	cc	CC	CCONJ	2	
4	blood	blood	conj	NN	NOUN	2	
5	products	product	pobj	NNS	NOUN	0	1,2
6	.	.	punct	.	PUNCT	0	'''

entry = parse(block)

# %%
PREPOSITIONS = ['about', 'across', 'against', 'along', 'among', 'around', 'as', 'at',
                'beside', 'besides', 'between', 'by', 'down', 'during', 
                'except', 'for', 'from', 'in', 'inside', 'into', 'of', 'off', 
                'on', 'onto', 'outside', 'over', 'through', 'to', 'toward', 'towards', 
                'under', 'underneath', 'until', 'up', 'upon', 'with', 'within', 'without']
# not inlcuded: above / behind / beneath /beyond / below ... 

WH_WORDS = ['how', 'who', 'what', 'when', 'why', 'where', 'which', 'whether', 'whichever', 'whoever', 'whomever', 'whatever', 'wherever', 'whenever']
RESERVED_WORDS = ['someway, together', 'that']

POS = {
    'VERB': ['VB', 'VBD', 'VBG', 'VBP', 'VBZ'], # 'VBN'
    'NOUN': ['NN', 'NNP', 'NNS', 'NNPS', 'DT', 'PRP', 'CD'],
    'ADJ':   ['JJ', 'JJR', 'JJS'],
    'ADV':   ['RB', 'RBR', 'RBS'],
    'PREP':  ['IN'],
    'WH':    ['WDT', 'WP', 'WP$', 'WRB']
}

DEP = {
    'SUB':  ['nsubj', 'nsubjpass', 'oprd'],
    'OBJ':  ['dobj', 'pobj'],
    'CL':   ['ccomp', 'xcomp', 'acomp', 'pcomp', 'csubj', 'csubjpass'],
    'PREP': ['prep', 'prt']
}

# %%
def classify_cl(token):
    if token.children:
        first_child = token.children[0]
        if first_child.tag in POS['WH']: return 'wh-cl'
        if first_child.tag == 'TO':      return 'to-v'
    return 'cl'
    
    
def head_mapping(token):
    if token.lemma == 'be':       return 'be'
    if token.tag == 'VBN':        return 'V-ed'
    if token.tag == 'VBG':        return 'V-ing'
    if token.tag in POS['VERB']:  return 'V'
    
    return None
    
    
def dep_mapping(token):
    # 順序 matters
    if token.dep in DEP['CL']:         return classify_cl(token)    
    
    if token.dep   == 'aux' and token['lemma'] == 'have': return 'have'
    if token.lemma == 'be':            return 'be'
    
    if token.tag == 'VBN':             return 'v-ed'
    if token.tag == 'VBG':             return 'v-ing'
    if token.tag in POS['VERB']:       return 'v'

    if token.dep in DEP['SUB']:        return 'S'
    if token.dep in DEP['OBJ']:        return 'O'
    if token.dep in DEP['PREP']:       return token.text
    if token.tag == 'TO':              return 'to'
    
    return None

# %%
####### Dependency pattern #######
# 第一層 dependency: dobj, prep, nsubj, nsubjpass, ccomp, xcomp, csubj, csubjpass, prt, acomp, oprd
# 第二層 dependency: prep -> pobj, pcomp

FIRST_REMAINS = ['aux', 'auxpass', 'dobj', 'prep', 'nsubj', 'nsubjpass', 'ccomp', 'xcomp', 'csubj', 'csubjpass', 'prt' 'acomp', 'oprd']
SECOND_REMAINS = ['pobj', 'pcomp']
go_deeper = ['prep']


def keep_children(children, rules):
    return [child for child in children if child.dep in rules]


def flattern(list_2d):
    return [el for li in list_2d for el in li]


# 先抓 Verb
def get_verb_dep(parsed, index):
    target = parsed[index]
    
    first_layer  = keep_children(target.children, FIRST_REMAINS)
    second_layer = flattern([keep_children(tk.children, SECOND_REMAINS) 
                             for tk in first_layer if tk.dep in go_deeper])
   
    tokens = [target] + first_layer + second_layer
    tokens.sort(key=lambda tk: tk.i)
    
    ptns = [head_mapping(tk) if tk.i == index else dep_mapping(tk) for tk in tokens]

    ptn = ' '.join([p for p in ptns if p]) # ignore None
    ngram = ' '.join([tk.text for tk in tokens])

    return ptn, ngram

# %%
# %%time
patterns = defaultdict(lambda: defaultdict(Counter))
ngrams = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: [])))
sents = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: [])))
    
def retrieve_dep(entry):
    sent = ' '.join([tk.text for tk in entry])
    for token in entry:
        if token.pos in POS['VERB']: # or tag == VERB
            ptn, ngram = get_verb_dep(entry, token.i)
            
            patterns[token.lemma][token.dep][ptn] += 1
            ngrams[token.lemma][token.dep][ptn].append(ngram)
            sents[token.lemma][token.dep][ptn].append(sent)
            
        elif token.pos in POS['ADJ']:
            pass


if __name__ == '__main__':
    fs = gzip.open('/force/corpus/COCA/coca.deps.spacy.tagged.gz', 'rt', encoding='utf8')
    contents = fs.read().split('\n\n')
    
    for entry in tqdm(contents):
        retrieve_dep(parse(entry))
# Out:
# 100%|██████████| 35136058/35136058 [1:23:35<00:00, 7005.61it/s]
# CPU times: user 1h 21min 52s, sys: 1min 8s, total: 1h 23min 1s
# Wall time: 1h 25min 56s

# %%
import json
with open('static/data/bnc.json', 'w', encoding='utf8') as ws:
    json.dump({ 'patterns': patterns, 'ngrams': ngrams, 'sents': sents }, ws)

# %%
patterns
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'inevitable': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'S O': 1})}),
#              'fixit': defaultdict(collections.Counter,
#                          {'acomp': Counter({'': 1})}),
#              '-thromboglobulin': defaultdict(collections.Counter,
#                          {'conj': Counter({'': 1}), 'nmod': Counter({'': 6})}),
#              'dance': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'': 13,
#                                    'Above O S O': 2,
#                                    'After O S O on O for O': 1,
#                                    'After cl S O': 1,
#                                    'At O O': 2,
#                                    'At O O cl': 1,
#                                    'At O S be O by O': 1,
#                                    'Before O S in O': 1,
#                                    'By cl S be': 1,
#                                    'For O S in O with O': 1,
#                                    'In O O S with O': 1,
#                                    'In O S': 2,
#                                    'In O S be to O': 1,
#                                    'In O be on O': 1,
#                                    'O': 10,
#                                    'O O': 1,
#                                    'O S': 1,
#                                    'O S to': 1,
#                                    'O S to from O': 1,
#                                    'O S with': 1,
#                                    'O into O': 1,
#                                    'O to O': 1,
#                                    'On O S': 1,
#                                    'On O S be to O': 1,
#                                    'On O S by O': 1,
#                                    'Over S through O': 1,
#                                    'S': 79,
#                                    'S O': 51,
#                                    'S O O': 1,
#                                    'S O at O': 2,
#                                    'S O before O as': 1,
#                                    'S O cl': 1,
#                                    'S O for O': 1,
#                                    'S O from cl': 1,
#                                    'S O in O until': 1,
#                                    'S O round': 1,
#                                    'S O through O': 1,
#                                    'S O with O': 2,
#                                    'S S': 1,
#                                    'S S for O': 1,
#                                    'S S like O': 1,
#                                    'S about O': 1,
#                                    'S about among O': 1,
#                                    'S about in O': 1,
#                                    'S according': 1,
#                                    'S across O': 6,
#                                    'S across O as O': 1,
#                                    'S among O': 1,
#                                    'S around O': 2,
#                                    'S as O': 1,
#                                    'S at O': 8,
#                                    'S at O from O': 1,
#                                    'S be': 25,
#                                    'S be O': 8,
#                                    'S be O by O': 1,
#                                    'S be O round': 1,
#                                    'S be O to O': 1,
#                                    'S be O with O at O': 1,
#                                    'S be about in O': 1,
#                                    'S be before O': 1,
#                                    'S be behind O': 1,
#                                    'S be cl': 1,
#                                    'S be for O': 1,
#                                    'S be in O': 3,
#                                    'S be in O over': 1,
#                                    'S be on O': 3,
#                                    'S be on O in O': 2,
#                                    'S be on O with O': 1,
#                                    'S be to O': 3,
#                                    'S be to O on O': 1,
#                                    'S be until O': 1,
#                                    'S be with O': 6,
#                                    'S be with O until O': 1,
#                                    'S before O': 2,
#                                    'S before O like O': 1,
#                                    'S behind O': 3,
#                                    'S beneath O': 1,
#                                    'S cl': 2,
#                                    'S down O': 1,
#                                    'S for': 1,
#                                    'S for O': 7,
#                                    'S for O for O': 1,
#                                    'S from O': 1,
#                                    'S have be O': 1,
#                                    'S have be at O': 1,
#                                    'S in O': 12,
#                                    'S in O before O': 1,
#                                    'S in O during O': 1,
#                                    'S in O following O': 1,
#                                    'S in O with O': 1,
#                                    'S like O': 5,
#                                    'S on O': 7,
#                                    'S on O be O at O': 1,
#                                    'S on O in O': 2,
#                                    'S on O on O': 2,
#                                    'S onto O': 1,
#                                    'S out': 2,
#                                    'S out O': 1,
#                                    'S round O': 1,
#                                    'S through O': 2,
#                                    'S through for O': 1,
#                                    'S to O': 19,
#                                    'S to O in O': 1,
#                                    'S to O without cl': 1,
#                                    'S to cl': 1,
#                                    'S under O': 1,
#                                    'S until O': 1,
#                                    'S with': 1,
#                                    'S with O': 38,
#                                    'S with O in O with O': 1,
#                                    'S without O as O': 1,
#                                    'To O S': 1,
#                                    'To O be S': 1,
#                                    'With O S out': 1,
#                                    'at O': 1,
#                                    'be': 5,
#                                    'be O': 1,
#                                    'be O cl': 1,
#                                    'be S': 1,
#                                    'be S O': 2,
#                                    'be S on O': 1,
#                                    'be above O': 1,
#                                    'be in O': 3,
#                                    'be in O to O': 1,
#                                    'be like': 1,
#                                    'be on O': 1,
#                                    'be to O': 1,
#                                    'cl': 2,
#                                    'cl S': 9,
#                                    'cl S O': 8,
#                                    'cl S above O': 1,
#                                    'cl S be': 1,
#                                    'cl S be on O': 1,
#                                    'cl S be with': 1,
#                                    'cl S be with O': 1,
#                                    'cl S into O': 1,
#                                    'cl S on O': 1,
#                                    'cl S to O O': 1,
#                                    'cl S with O': 3,
#                                    'cl S with O on O': 1,
#                                    'cl S with O with O': 1,
#                                    'cl as S for O': 1,
#                                    'cl be in O': 1,
#                                    'cl on O S be': 1,
#                                    'during O S O with O': 1,
#                                    'in O': 1,
#                                    'in O S be O': 1,
#                                    'in O S in O': 1,
#                                    'of O S till O': 1,
#                                    'on O': 2,
#                                    'on O O in O': 1,
#                                    'on cl S': 1,
#                                    'past O': 1,
#                                    'with O': 4}),
#                           'acl': Counter({'': 10,
#                                    'O': 4,
#                                    'S O': 1,
#                                    'S as O': 2,
#                                    'S be': 1,
#                                    'S on O during O': 1,
#                                    'S through O': 1,
#                                    'around O': 2,
#                                    'at O': 1,
#                                    'cl S O': 1,
#                                    'from O': 1,
#                                    'in': 1,
#                                    'in O': 1,
#                                    'in O at O': 1,
#                                    'in O in O': 1,
#                                    'on O': 3,
#                                    'opposite O': 1,
#                                    'through O': 2,
#                                    'throughout': 1,
#                                    'to O': 1,
#                                    'to O to O': 1,
#                                    'with O': 2}),
#                           'advcl': Counter({'': 29,
#                                    'O': 13,
#                                    'O O to O in O': 1,
#                                    'O as O': 1,
#                                    'O at O': 1,
#                                    'O in O': 1,
#                                    'O on O on O': 1,
#                                    'O to': 1,
#                                    'O to O': 1,
#                                    'O with O': 1,
#                                    'S': 40,
#                                    'S O': 10,
#                                    'S O in O': 1,
#                                    'S about O': 1,
#                                    'S across O towards O': 1,
#                                    'S against O': 1,
#                                    'S around O': 2,
#                                    'S as': 1,
#                                    'S at O': 2,
#                                    'S be': 5,
#                                    'S be O': 1,
#                                    'S be O at O': 1,
#                                    'S be O in O': 1,
#                                    'S be cl': 1,
#                                    'S be like O': 1,
#                                    'S be with O': 1,
#                                    'S before O': 1,
#                                    'S cl': 1,
#                                    'S for O': 1,
#                                    'S in O': 3,
#                                    'S in O at O': 1,
#                                    'S like O': 1,
#                                    'S on O': 1,
#                                    'S to': 2,
#                                    'S to O': 4,
#                                    'S with': 1,
#                                    'S with O': 6,
#                                    'S with O in O': 1,
#                                    'S with O to O during O': 1,
#                                    'S with on O': 1,
#                                    'S without O': 1,
#                                    'across O': 2,
#                                    'across O in O': 1,
#                                    'alongside O': 1,
#                                    'at O': 2,
#                                    'following O S': 1,
#                                    'in O': 7,
#                                    'into O': 1,
#                                    'like O': 1,
#                                    'on O': 5,
#                                    'past O in O': 1,
#                                    'through O until O': 1,
#                                    'to O': 6,
#                                    'to O throughout O': 1,
#                                    'with': 1,
#                                    'with O': 13}),
#                           'advmod': Counter({'': 2}),
#                           'amod': Counter({'': 8}),
#                           'appos': Counter({'': 1,
#                                    'S as O': 1,
#                                    'at O': 1,
#                                    'in O': 1,
#                                    'on O': 1,
#                                    'with O': 1}),
#                           'attr': Counter({'': 1,
#                                    'S': 1,
#                                    'in O': 1,
#                                    'into O': 1}),
#                           'ccomp': Counter({'': 1,
#                                    'For O S in O': 1,
#                                    'For O S out': 1,
#                                    'O S S': 1,
#                                    'O S to': 2,
#                                    'S': 60,
#                                    'S O': 19,
#                                    'S O as O': 1,
#                                    'S O at O at O': 1,
#                                    'S O like O': 1,
#                                    'S O to O': 2,
#                                    'S O with O': 3,
#                                    'S O without cl': 1,
#                                    'S S S O in O': 1,
#                                    'S about O': 2,
#                                    'S among O': 1,
#                                    'S at O': 3,
#                                    'S be': 14,
#                                    'S be O': 5,
#                                    'S be O with O': 1,
#                                    'S be for O': 1,
#                                    'S be in O': 1,
#                                    'S be on O': 1,
#                                    'S be to O': 3,
#                                    'S be with': 1,
#                                    'S be with O': 2,
#                                    'S behind O between O': 1,
#                                    'S cl': 1,
#                                    'S for O': 1,
#                                    'S from O to O in O': 1,
#                                    'S in': 1,
#                                    'S in O': 3,
#                                    'S into O': 1,
#                                    'S like O': 3,
#                                    'S on O': 4,
#                                    'S till O': 1,
#                                    'S to O': 6,
#                                    'S to O under O': 1,
#                                    'S with O': 17,
#                                    'S with O in O': 1,
#                                    'S with cl': 1,
#                                    'be at O': 1,
#                                    'be in O': 2,
#                                    'cl S be': 1,
#                                    'cl S in O': 1,
#                                    'cl S in O in O': 1,
#                                    'cl S on O': 1,
#                                    'in O': 1,
#                                    'of O S': 1,
#                                    'with O with O': 1}),
#                           'compound': Counter({'': 11, 'S': 2}),
#                           'conj': Counter({'': 54,
#                                    'O': 28,
#                                    'O across O': 1,
#                                    'O amid O': 1,
#                                    'O before O': 1,
#                                    'O before cl': 1,
#                                    'O like O': 1,
#                                    'O on O': 1,
#                                    'O out': 1,
#                                    'O through O': 1,
#                                    'O to O': 4,
#                                    'O with cl': 1,
#                                    'S': 27,
#                                    'S O': 5,
#                                    'S O on O': 1,
#                                    'S O through O': 1,
#                                    'S O to O': 1,
#                                    'S across O': 2,
#                                    'S against O': 1,
#                                    'S at O': 1,
#                                    'S be': 7,
#                                    'S be O': 1,
#                                    'S be O in O': 1,
#                                    'S be O on O': 1,
#                                    'S be about O': 1,
#                                    'S be since O': 1,
#                                    'S be to O': 3,
#                                    'S be with O': 6,
#                                    'S cl': 1,
#                                    'S from O to O': 1,
#                                    'S have be since O': 1,
#                                    'S in O': 6,
#                                    'S into O': 1,
#                                    'S like': 2,
#                                    'S like O': 2,
#                                    'S of O': 1,
#                                    'S on O': 1,
#                                    'S on O in O': 1,
#                                    'S through O': 1,
#                                    'S to O': 4,
#                                    'S under O': 1,
#                                    'S until O': 1,
#                                    'S with O': 4,
#                                    'S with O in O': 1,
#                                    'S with O to O': 1,
#                                    'S without': 1,
#                                    'about in O': 1,
#                                    'about on O': 1,
#                                    'across O': 1,
#                                    'around O': 1,
#                                    'as O': 1,
#                                    'at O': 4,
#                                    'be O on O': 1,
#                                    'be about in O': 1,
#                                    'be on O at in O like': 1,
#                                    'be with O': 1,
#                                    'beneath O': 1,
#                                    'for O': 3,
#                                    'from O on': 1,
#                                    'in': 1,
#                                    'in O': 10,
#                                    'in O O': 1,
#                                    'like O': 1,
#                                    'on O': 4,
#                                    'on O in O': 1,
#                                    'on O with O': 1,
#                                    'through O': 1,
#                                    'to O': 7,
#                                    'to O to O': 1,
#                                    'upon O like O': 1,
#                                    'with': 1,
#                                    'with O': 11,
#                                    'with O at O': 1,
#                                    'with O into O': 1,
#                                    'with O to O': 2}),
#                           'csubj': Counter({'S': 1,
#                                    'under O to O': 1,
#                                    'with O': 1}),
#                           'dep': Counter({'O': 2, 'O in O': 1, 'with O': 1}),
#                           'dobj': Counter({'': 18,
#                                    'O': 2,
#                                    'S': 2,
#                                    'S in O': 1,
#                                    'against O': 1,
#                                    'as O': 1,
#                                    'for O': 1,
#                                    'in O': 1,
#                                    'to O from O': 1,
#                                    'with O': 1}),
#                           'npadvmod': Counter({'': 1}),
#                           'nsubj': Counter({'': 3,
#                                    'S': 1,
#                                    'S O': 2,
#                                    'in O': 1,
#                                    'on O': 1}),
#                           'nsubjpass': Counter({'around O': 1}),
#                           'parataxis': Counter({'S': 1}),
#                           'pcomp': Counter({'': 6,
#                                    'O': 7,
#                                    'O about O': 1,
#                                    'O for O': 1,
#                                    'O to O': 1,
#                                    'S': 3,
#                                    'S O': 4,
#                                    'S O behind O': 1,
#                                    'S be to O': 1,
#                                    'S cl': 2,
#                                    'S to O': 1,
#                                    'across O': 1,
#                                    'in O': 2,
#                                    'through O': 1,
#                                    'to O': 1,
#                                    'with O': 3}),
#                           'pobj': Counter({'': 18,
#                                    'S': 2,
#                                    'Through O': 1,
#                                    'by O': 1,
#                                    'in O': 3,
#                                    'of O': 1,
#                                    'on O with O': 1,
#                                    'with O': 1}),
#                           'poss': Counter({'': 1}),
#                           'relcl': Counter({'': 16,
#                                    'O': 3,
#                                    'O S according': 1,
#                                    'S': 18,
#                                    'S O': 12,
#                                    'S O down O': 1,
#                                    'S O to O': 1,
#                                    'S O upon O': 1,
#                                    'S S have be at O': 1,
#                                    'S across O': 2,
#                                    'S around O': 1,
#                                    'S be': 2,
#                                    'S be O': 1,
#                                    'S be in O': 1,
#                                    'S be with': 2,
#                                    'S be with O': 3,
#                                    'S before O': 2,
#                                    'S between O': 1,
#                                    'S except': 1,
#                                    'S for O inside O': 1,
#                                    'S from O': 1,
#                                    'S have be': 1,
#                                    'S have be O': 1,
#                                    'S have be for O': 1,
#                                    'S in': 1,
#                                    'S in O': 6,
#                                    'S like O': 1,
#                                    'S on O': 3,
#                                    'S on O with O': 1,
#                                    'S to O': 3,
#                                    'S to in O': 1,
#                                    'S until O': 1,
#                                    'S with': 1,
#                                    'S with O': 5,
#                                    'S with O at O': 2,
#                                    'about': 1,
#                                    'along O S': 1,
#                                    'at O': 1,
#                                    'in O': 1,
#                                    'in O S': 1,
#                                    'in O S from O': 1,
#                                    'to': 1,
#                                    'to O': 1,
#                                    'to O S': 1,
#                                    'with': 3,
#                                    'with O S': 1,
#                                    'with O S at O': 1}),
#                           'xcomp': Counter({'': 143,
#                                    'O': 24,
#                                    'O at O': 2,
#                                    'O in O': 1,
#                                    'O through O': 1,
#                                    'O to O': 1,
#                                    'O with O': 2,
#                                    'S': 1,
#                                    'among O': 1,
#                                    'at O': 5,
#                                    'at cl': 1,
#                                    'be': 4,
#                                    'be among O': 1,
#                                    'before O': 1,
#                                    'beyond O': 1,
#                                    'by O': 1,
#                                    'by O at O': 1,
#                                    'cl': 1,
#                                    'despite O': 1,
#                                    'during O': 1,
#                                    'for O': 5,
#                                    'in O': 6,
#                                    'like O': 2,
#                                    'on O': 3,
#                                    'through O': 1,
#                                    'to': 2,
#                                    'to O': 4,
#                                    'upon O': 1,
#                                    'with': 2,
#                                    'with O': 28,
#                                    'with O by O before cl': 1,
#                                    'with O during O': 1,
#                                    'with O in O': 1,
#                                    'with cl': 1})}),
#              'tuilaepa': defaultdict(collections.Counter,
#                          {'compound': Counter({'': 1})}),
#              'hid': defaultdict(collections.Counter,
#                          {'xcomp': Counter({'O': 2, 'O from O': 2})}),
#              'redesign': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'At O S': 1,
#                                    'At O S O': 1,
#                                    'At O S be': 1,
#                                    'In O S be O': 1,
#                                    'O according': 1,
#                                    'S O': 3,
#                                    'S O cl': 1,
#                                    'S O for O': 1,
#                                    'S S be O for O': 1}),
#                           'acl': Counter({'': 1, 'O': 2}),
#                           'advcl': Counter({'O': 5,
#                                    'O cl': 1,
#                                    'S O': 1,
#                                    'S O cl': 1}),
#                           'ccomp': Counter({'S O': 3}),
#                           'conj': Counter({'O': 5,
#                                    'O as O': 1,
#                                    'O in O': 1,
#                                    'O on O': 1,
#                                    'S O': 1,
#                                    'S O cl': 1}),
#                           'csubj': Counter({'': 1, 'O': 2}),
#                           'dobj': Counter({'of O': 1}),
#                           'nsubjpass': Counter({'with O': 1}),
#                           'pcomp': Counter({'': 1,
#                                    'O': 18,
#                                    'O as O': 1,
#                                    'O in O': 1,
#                                    'O on O': 1,
#                                    'O to O': 1,
#                                    'O to cl': 1,
#                                    'from O': 1,
#                                    'in O by cl': 1}),
#                           'relcl': Counter({'O': 2, 'O in O': 1}),
#                           'xcomp': Counter({'': 3,
#                                    'O': 17,
#                                    'O along O': 1,
#                                    'O in O': 1})}),
#              'moisturise': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'O': 1,
#                                    'O with O': 1,
#                                    'S': 2,
#                                    'S be O for O': 1}),
#                           'advcl': Counter({'': 1, 'S O': 1, 'with O': 1}),
#                           'amod': Counter({'': 21}),
#                           'ccomp': Counter({'S': 1, 'like O': 1}),
#                           'conj': Counter({'': 11, 'O': 4, 'O with O': 1}),
#                           'relcl': Counter({'S': 1}),
#                           'xcomp': Counter({'': 1})}),
#              'sp': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'S O': 1})}),
#              'reclassify': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'By O S O with O': 1,
#                                    'In O S O as O': 1,
#                                    'S O': 1,
#                                    'S O in O': 1}),
#                           'acl': Counter({'': 2, 'O according': 1}),
#                           'advcl': Counter({'': 1, 'S': 1}),
#                           'conj': Counter({'O': 1}),
#                           'pcomp': Counter({'O': 1}),
#                           'relcl': Counter({'S O as O': 1}),
#                           'xcomp': Counter({'O': 2})}),
#              'ejaculate': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'O': 4,
#                                    'O on O': 1,
#                                    'S': 2,
#                                    'S O': 1,
#                                    'S cl': 1,
#                                    'S into O': 1}),
#                           'advcl': Counter({'S at O': 1,
#                                    'S before cl': 1,
#                                    'S into O': 1}),
#                           'appos': Counter({'': 1}),
#                           'ccomp': Counter({'S': 1, 'S O': 1}),
#                           'conj': Counter({'O': 2}),
#                           'nsubj': Counter({'': 1}),
#                           'parataxis': Counter({'O': 1}),
#                           'pcomp': Counter({'': 2}),
#                           'relcl': Counter({'': 1, 'O S': 1, 'S': 1}),
#                           'xcomp': Counter({'': 2})}),
#              'whimper': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'': 1,
#                                    'O': 5,
#                                    'S': 26,
#                                    'S O': 2,
#                                    'S O over O': 1,
#                                    'S at O': 1,
#                                    'S at O cl': 1,
#                                    'S be': 3,
#                                    'S be in O': 1,
#                                    'S be with O': 2,
#                                    'S cl': 1,
#                                    'S into O': 1,
#                                    'S like O': 1,
#                                    'S to O': 1,
#                                    'S with O': 3,
#                                    'cl S': 1,
#                                    'cl S O': 1,
#                                    'cl S S': 1,
#                                    'from cl by': 1}),
#                           'acl': Counter({'': 2, 'at O': 1, 'like O': 1}),
#                           'advcl': Counter({'': 9,
#                                    'O': 2,
#                                    'O cl': 1,
#                                    'S': 1,
#                                    'at O': 1,
#                                    'in O': 2,
#                                    'like O': 1,
#                                    'outside O': 1,
#                                    'with O': 1}),
#                           'amod': Counter({'': 1}),
#                           'ccomp': Counter({'O S at O': 1,
#                                    'S': 10,
#                                    'S cl': 1,
#                                    'S outside O': 1}),
#                           'conj': Counter({'': 4,
#                                    'O': 2,
#                                    'S': 3,
#                                    'S be': 1,
#                                    'for O': 2,
#                                    'in O': 2,
#                                    'like O': 1}),
#                           'intj': Counter({'': 1}),
#                           'oprd': Counter({'as O': 1}),
#                           'parataxis': Counter({'S': 1}),
#                           'pobj': Counter({'': 1}),
#                           'xcomp': Counter({'': 10,
#                                    'in O': 1,
#                                    'in O by O': 1,
#                                    'with O': 1})}),
#              'polygyny': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'In O O': 1}),
#                           'conj': Counter({'O': 1})}),
#              'henchard': defaultdict(collections.Counter,
#                          {'nmod': Counter({'': 1})}),
#              'calcu': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'cl S': 1})}),
#              'goldheart': defaultdict(collections.Counter,
#                          {'pobj': Counter({'': 1})}),
#              'gall': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'O': 1,
#                                    'S O': 2,
#                                    'S O cl': 2,
#                                    'S O like O': 1,
#                                    'S S O': 1,
#                                    'S be in O': 2}),
#                           'acl': Counter({'O in O': 1}),
#                           'advcl': Counter({'O': 2,
#                                    'S O': 1,
#                                    'S O among O for O': 1}),
#                           'ccomp': Counter({'S O': 1, 'S O cl': 1}),
#                           'compound': Counter({'': 3}),
#                           'csubj': Counter({'': 1}),
#                           'pcomp': Counter({'S': 1}),
#                           'relcl': Counter({'be in O': 1}),
#                           'xcomp': Counter({'': 1, 'O': 3})}),
#              'salmon': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'': 1, 'S O': 1}),
#                           'conj': Counter({'': 1}),
#                           'dep': Counter({'WITH O': 1}),
#                           'pobj': Counter({'': 1})}),
#              'counteract': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'O': 7,
#                                    'O in O': 1,
#                                    'S O': 6,
#                                    'S O by cl': 2,
#                                    'S be O': 1,
#                                    'S be O by cl': 1,
#                                    'at O S O': 1,
#                                    'cl': 2,
#                                    'cl S O': 1}),
#                           'acl': Counter({'O': 18, 'S O': 1}),
#                           'advcl': Counter({'': 1,
#                                    'O': 45,
#                                    'O according': 1,
#                                    'O during O': 1,
#                                    'O through O': 1,
#                                    'S O': 1,
#                                    'S O by cl': 1,
#                                    'S at O O': 1}),
#                           'ccomp': Counter({'': 1, 'S': 1, 'S O': 4}),
#                           'conj': Counter({'O': 14,
#                                    'O in O': 1,
#                                    'O on O': 1,
#                                    'O towards O': 1,
#                                    'S O': 2,
#                                    'S O to O': 1,
#                                    'S in O O': 1,
#                                    'by cl O': 1,
#                                    'cl': 1,
#                                    'in O O': 1,
#                                    'in O S be O': 1}),
#                           'csubj': Counter({'O': 3}),
#                           'pcomp': Counter({'': 1,
#                                    'O': 11,
#                                    'O to O of cl': 1,
#                                    'S O': 1}),
#                           'poss': Counter({'': 1}),
#                           'relcl': Counter({'O': 18,
#                                    'S O': 7,
#                                    'S to O O': 1,
#                                    'by O S O': 1}),
#                           'xcomp': Counter({'': 5,
#                                    'O': 49,
#                                    'O O': 1,
#                                    'O O by cl': 1,
#                                    'O as': 1,
#                                    'O by cl': 4,
#                                    'O by for O': 1,
#                                    'O with O': 1,
#                                    'on O': 1})}),
#              'dribble': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'': 2,
#                                    'O': 2,
#                                    'S': 6,
#                                    'S O': 4,
#                                    'S O from O': 1,
#                                    'S O from O on to O': 1,
#                                    'S O onto O from O': 1,
#                                    'S S on O': 1,
#                                    'S at O': 1,
#                                    'S be': 1,
#                                    'S be across O on O': 1,
#                                    'S be with O': 1,
#                                    'S from O': 3,
#                                    'S from O to O': 1,
#                                    'S into O through O': 1,
#                                    'S like O': 1,
#                                    'S over O': 1,
#                                    'S past O towards O': 1,
#                                    'beside O be S': 1,
#                                    'cl S': 1,
#                                    'cl S from O': 2,
#                                    'to O': 1}),
#                           'acl': Counter({'': 1,
#                                    'O': 1,
#                                    'O into O': 1,
#                                    'for O': 1,
#                                    'from O': 2,
#                                    'with O': 3}),
#                           'advcl': Counter({'': 2,
#                                    'S': 1,
#                                    'S O': 2,
#                                    'S be be': 1,
#                                    'S from O onto O': 1,
#                                    'S into O': 3,
#                                    'S out': 1,
#                                    'across O': 1}),
#                           'amod': Counter({'': 1}),
#                           'appos': Counter({'for O': 1}),
#                           'ccomp': Counter({'O around O': 1,
#                                    'S': 3,
#                                    'S O': 3,
#                                    'S at O': 1,
#                                    'S because cl O': 1,
#                                    'S for O': 1,
#                                    'S in O': 1,
#                                    'S in O despite cl': 1}),
#                           'conj': Counter({'': 5,
#                                    'O': 7,
#                                    'O between O': 1,
#                                    'O for O': 1,
#                                    'O onto O': 1,
#                                    'S': 2,
#                                    'S be': 1,
#                                    'S from O': 2,
#                                    'from O': 1,
#                                    'out': 1}),
#                           'csubj': Counter({'through O': 1}),
#                           'dep': Counter({'': 1}),
#                           'dobj': Counter({'O': 1, 'S': 1}),
#                           'pcomp': Counter({'O through O': 1,
#                                    'S': 1,
#                                    'S O': 1,
#                                    'S into into O': 1}),
#                           'relcl': Counter({'S': 2,
#                                    'S O': 2,
#                                    'S about O': 1,
#                                    'S from O': 1}),
#                           'xcomp': Counter({'': 6,
#                                    'O': 2,
#                                    'O across O': 1,
#                                    'O from': 1,
#                                    'O from O': 1,
#                                    'O past O': 1,
#                                    'across O': 1,
#                                    'down O': 1,
#                                    'on O': 1,
#                                    'with O': 1})}),
#              'outspeed': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'S O': 1}),
#                           'conj': Counter({'': 1}),
#                           'xcomp': Counter({'O': 1})}),
#              'sing': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'': 44,
#                                    'Above O S O': 1,
#                                    'Above O S in O': 1,
#                                    'After O S O': 1,
#                                    'After O S S O': 1,
#                                    'Amid O S be in O': 1,
#                                    'As O S alongside O': 1,
#                                    'At O S': 2,
#                                    'At O S O': 3,
#                                    'At O S S': 1,
#                                    'At O S S O': 1,
#                                    'At O S as O': 1,
#                                    'At O S of O': 1,
#                                    'Behind O S': 1,
#                                    'Behind O S be O': 1,
#                                    'By O S be': 2,
#                                    'By cl S have be O at O': 1,
#                                    'Despite O S O': 1,
#                                    'During O S': 1,
#                                    'During O S O': 1,
#                                    'FROM O': 1,
#                                    'FROM O S be O': 1,
#                                    'For O O O': 1,
#                                    'For O S O': 2,
#                                    'For O S in O': 1,
#                                    'For O on O S be O O': 1,
#                                    'From O S of': 1,
#                                    'IN O S of O': 1,
#                                    'In O O': 1,
#                                    'In O O S cl': 1,
#                                    'In O S': 7,
#                                    'In O S O': 8,
#                                    'In O S O as O': 1,
#                                    'In O S be': 3,
#                                    'In O S be O': 1,
#                                    'In O S be O O': 1,
#                                    'In O S be O for O with O': 1,
#                                    'In O S be to O': 1,
#                                    'In O S cl': 3,
#                                    'In O S to O': 1,
#                                    'In O by O S O': 1,
#                                    'In S': 1,
#                                    'Inside O be': 1,
#                                    'O': 82,
#                                    'O O': 1,
#                                    'O O S': 1,
#                                    'O O S in O': 1,
#                                    'O S': 7,
#                                    'O S O O S to cl': 1,
#                                    'O S at O': 1,
#                                    'O S be': 2,
#                                    'O S have be to O': 1,
#                                    'O S without O': 1,
#                                    'O about': 1,
#                                    'O about O O in O': 1,
#                                    'O be S': 2,
#                                    'O for O': 1,
#                                    'O from': 1,
#                                    'O from O': 1,
#                                    'O in': 1,
#                                    'O in O': 2,
#                                    'O into O': 2,
#                                    'O like like': 1,
#                                    'O on O': 1,
#                                    'O to O': 3,
#                                    'O to O in O': 1,
#                                    'O with O': 1,
#                                    'O with O as O': 1,
#                                    'On O O': 2,
#                                    'On O S O out': 1,
#                                    'On O S about O with O': 1,
#                                    'On O S be': 1,
#                                    'On O S in O at O': 1,
#                                    'S': 221,
#                                    'S For O': 1,
#                                    'S O': 246,
#                                    'S O O': 5,
#                                    'S O about': 1,
#                                    'S O as O cl': 1,
#                                    'S O at O': 3,
#                                    'S O below O': 1,
#                                    'S O cl': 3,
#                                    'S O during O': 1,
#                                    'S O for O': 1,
#                                    'S O from O': 3,
#                                    'S O from O cl': 1,
#                                    'S O in O': 14,
#                                    'S O in O for O': 1,
#                                    'S O in O of O': 1,
#                                    'S O in O with cl': 1,
#                                    'S O on O': 2,
#                                    'S O on O at O in O': 1,
#                                    'S O out': 1,
#                                    'S O to': 1,
#                                    'S O to O': 9,
#                                    'S O with O': 6,
#                                    'S O without O': 1,
#                                    'S O without O cl': 1,
#                                    'S S': 6,
#                                    'S S O': 5,
#                                    'S S O cl': 1,
#                                    'S S after cl': 1,
#                                    'S S be': 1,
#                                    'S S be O': 3,
#                                    'S S cl': 1,
#                                    'S S in O': 1,
#                                    'S about O': 3,
#                                    'S about cl': 1,
#                                    'S above O': 2,
#                                    'S above O O': 1,
#                                    'S against O': 1,
#                                    'S against O across O': 1,
#                                    'S along': 1,
#                                    'S along O': 1,
#                                    'S as O': 3,
#                                    'S at O': 7,
#                                    'S at O at O for O': 1,
#                                    'S at O in O': 1,
#                                    'S at O on O': 2,
#                                    'S be': 62,
#                                    'S be O': 39,
#                                    'S be O at O': 1,
#                                    'S be O at O for O': 1,
#                                    'S be O cl': 3,
#                                    'S be O from O': 1,
#                                    'S be O in O': 1,
#                                    'S be O out': 1,
#                                    'S be O to': 1,
#                                    'S be O to O': 1,
# ...
#                          {'ROOT': Counter({'S cl': 1}),
#                           'attr': Counter({'to O': 1}),
#                           'relcl': Counter({'S': 1})}),
#              'realia': defaultdict(collections.Counter,
#                          {'conj': Counter({'like O at O': 1})}),
#              'libb': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'S O through O': 1})}),
#              'cadet': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'S into O': 1, 'in O O on O': 1})}),
#              'detrain': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'S at': 1}),
#                           'advcl': Counter({'S': 1}),
#                           'pcomp': Counter({'at O for O': 1}),
#                           'xcomp': Counter({'': 1})}),
#              'wrench': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'At O S O': 1,
#                                    'From O S O': 1,
#                                    'In O S': 1,
#                                    'O': 2,
#                                    'O from O': 1,
#                                    'O in O': 1,
#                                    'O to O': 1,
#                                    'S': 5,
#                                    'S O': 45,
#                                    'S O O': 3,
#                                    'S O cl': 1,
#                                    'S O from O': 8,
#                                    'S O from O at O': 2,
#                                    'S O into O': 1,
#                                    'S O like O': 1,
#                                    'S O off O': 2,
#                                    'S O out': 2,
#                                    'S S': 1,
#                                    'S S O cl': 1,
#                                    'S at O': 2,
#                                    'With O S O': 2,
#                                    'With O S O out': 1,
#                                    'With O S O to O': 1,
#                                    'With cl S O from O': 1,
#                                    'Without S O S into O': 1,
#                                    'Without cl S O': 1,
#                                    'cl O': 1,
#                                    'cl S O': 2,
#                                    'cl S at O': 1,
#                                    'with cl S O off O': 1}),
#                           'acl': Counter({'O': 1, 'O from O': 2, 'S at O': 1}),
#                           'acomp': Counter({'': 1}),
#                           'advcl': Counter({'O': 17,
#                                    'O S': 5,
#                                    'O against O': 1,
#                                    'O from O': 3,
#                                    'O into O': 1,
#                                    'O out': 1,
#                                    'S': 3,
#                                    'S O': 8,
#                                    'S O from O': 1,
#                                    'S on cl O': 1,
#                                    'at O': 1,
#                                    'cl': 1,
#                                    'out O': 3}),
#                           'advmod': Counter({'': 1}),
#                           'amod': Counter({'': 12}),
#                           'ccomp': Counter({'O S from O': 1,
#                                    'S': 1,
#                                    'S O': 1,
#                                    'S O from O': 1,
#                                    'S O out': 2,
#                                    'S at O': 1,
#                                    'S be from O': 1,
#                                    'S out': 1,
#                                    'To O at O': 1}),
#                           'conj': Counter({'': 5,
#                                    'O': 19,
#                                    'O from O': 5,
#                                    'O into O': 1,
#                                    'O out': 2,
#                                    'O with O': 1,
#                                    'S O': 5,
#                                    'S O from O': 3,
#                                    'S O on O': 1,
#                                    'S O out': 1,
#                                    'S O with O': 2,
#                                    'S to O': 1,
#                                    'S with O': 1,
#                                    'cl': 2,
#                                    'like O S O': 1,
#                                    'on O S O with O': 1,
#                                    'out': 1,
#                                    'until cl': 1,
#                                    'with O S O': 1}),
#                           'csubj': Counter({'O from O': 2}),
#                           'oprd': Counter({'': 1, 'O': 1}),
#                           'parataxis': Counter({'S O S': 1}),
#                           'pcomp': Counter({'O': 1,
#                                    'O from O': 1,
#                                    'O off O': 1,
#                                    'O on': 1,
#                                    'open': 1}),
#                           'relcl': Counter({'O from O': 1,
#                                    'S O': 2,
#                                    'S at O': 1,
#                                    'from O S O in O': 1}),
#                           'xcomp': Counter({'': 2,
#                                    'O': 8,
#                                    'O S': 6,
#                                    'O from O': 6,
#                                    'O out': 1,
#                                    'O to O': 1,
#                                    'O up': 1})}),
#              'correct': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'': 8,
#                                    'As O S O': 1,
#                                    'At O S O': 1,
#                                    'At O S O by cl': 1,
#                                    'Following O S O to O': 1,
#                                    'For O S': 1,
#                                    'In O O': 1,
#                                    'In O O by cl': 1,
#                                    'In O S': 1,
#                                    'In O S O': 2,
#                                    'In O S O with O': 2,
#                                    'In O S on O O by cl': 1,
#                                    'O': 56,
#                                    'O O': 1,
#                                    'O S': 1,
#                                    'O S O': 1,
#                                    'O as O': 1,
#                                    'O at cl': 1,
#                                    'O by cl': 1,
#                                    'On O S': 1,
#                                    'S': 38,
#                                    'S O': 86,
#                                    'S O O': 1,
#                                    'S O at O': 1,
#                                    'S O before cl': 1,
#                                    'S O between O': 1,
#                                    'S O by': 1,
#                                    'S O by cl': 2,
#                                    'S O cl': 3,
#                                    'S O for O': 2,
#                                    'S O from O': 1,
#                                    'S O in O': 2,
#                                    'S O of O': 1,
#                                    'S O on O': 3,
#                                    'S O to O': 1,
#                                    'S O with O': 2,
#                                    'S O without O': 1,
#                                    'S S': 3,
#                                    'S S O': 7,
#                                    'S S O on O at O': 1,
#                                    'S as': 1,
#                                    'S at O': 4,
#                                    'S be O': 1,
#                                    'S be O about O': 1,
#                                    'S be O for O': 1,
#                                    'S be O with O': 1,
#                                    'S be on O': 1,
#                                    'S between O': 1,
#                                    'S cl': 1,
#                                    'S for O': 1,
#                                    'S for O by cl': 1,
#                                    'S to O': 2,
#                                    'be O': 1,
#                                    'cl O': 3,
#                                    'cl S': 12,
#                                    'cl S O': 8,
#                                    'cl S cl': 1,
#                                    'cl S with O': 1,
#                                    'for O S O': 2,
#                                    'for O by O': 1,
#                                    'have O': 1,
#                                    'have S': 1,
#                                    'in O S with O in O': 1}),
#                           'acl': Counter({'': 4,
#                                    'O': 28,
#                                    'O in O': 1,
#                                    'O into O': 1,
#                                    'O with O': 1,
#                                    'O within O': 1,
#                                    'S': 3,
#                                    'S O': 2,
#                                    'S O by cl': 1,
#                                    'cl': 1,
#                                    'since': 1}),
#                           'acomp': Counter({'': 7,
#                                    'O': 1,
#                                    'S': 1,
#                                    'S cl': 1,
#                                    'cl': 3}),
#                           'advcl': Counter({'': 10,
#                                    'O': 103,
#                                    'O O': 2,
#                                    'O cl': 1,
#                                    'O in': 1,
#                                    'O in O': 2,
#                                    'S': 7,
#                                    'S O': 22,
#                                    'S O by cl': 1,
#                                    'S O in O': 1,
#                                    'S O on O': 1,
#                                    'S be O': 2,
#                                    'cl': 2,
#                                    'cl O': 1,
#                                    'for O': 7,
#                                    'for cl': 1,
#                                    'with O': 1}),
#                           'amod': Counter({'': 20, 'with O': 1}),
#                           'attr': Counter({'': 1}),
#                           'ccomp': Counter({'': 1,
#                                    'At O S O': 1,
#                                    'By O S O': 1,
#                                    'In O O': 1,
#                                    'O': 4,
#                                    'O S': 1,
#                                    'S': 17,
#                                    'S O': 41,
#                                    'S O O': 1,
#                                    'S O against': 1,
#                                    'S O at O': 1,
#                                    'S O before cl': 1,
#                                    'S O cl': 2,
#                                    'S O on O': 1,
#                                    'S S': 1,
#                                    'S be O': 1,
#                                    'S be O as': 1,
#                                    'S cl': 4,
#                                    'S for O': 1,
#                                    'S in cl': 1,
#                                    'S with O': 1,
#                                    'S without cl': 1,
#                                    'cl O': 1}),
#                           'compound': Counter({'': 2}),
#                           'conj': Counter({'': 14,
#                                    'O': 87,
#                                    'O as': 2,
#                                    'O by O': 3,
#                                    'O by cl': 1,
#                                    'O cl': 2,
#                                    'O for O': 2,
#                                    'O for O though O': 1,
#                                    'O for cl': 1,
#                                    'O if': 2,
#                                    'O in O': 1,
#                                    'O to O': 2,
#                                    'O without O': 1,
#                                    'O without cl': 1,
#                                    'S': 1,
#                                    'S O': 4,
#                                    'S O for O': 1,
#                                    'S O in O': 1,
#                                    'S O with O': 1,
#                                    'S O without cl': 1,
#                                    'S after cl': 1,
#                                    'S be O O': 1,
#                                    'S be O on O': 1,
#                                    'S be O with on O': 1,
#                                    'S on O in O': 1,
#                                    'at O': 1,
#                                    'cl': 2,
#                                    'for O': 2,
#                                    'in O': 2,
#                                    'to O': 1}),
#                           'csubj': Counter({'O': 6, 'O at O': 1, 'S O': 1}),
#                           'csubjpass': Counter({'O O': 1}),
#                           'dep': Counter({'O': 2, 'O cl': 1}),
#                           'parataxis': Counter({'': 1}),
#                           'pcomp': Counter({'': 3,
#                                    'O': 38,
#                                    'O O': 1,
#                                    'O before cl': 1,
#                                    'O by cl': 1,
#                                    'O for O': 1,
#                                    'O in O': 1,
#                                    'O with O': 1,
#                                    'cl': 1,
#                                    'for O': 4}),
#                           'relcl': Counter({'': 5,
#                                    'O': 18,
#                                    'O S': 1,
#                                    'O by O': 1,
#                                    'O by cl': 1,
#                                    'O from O': 1,
#                                    'S': 2,
#                                    'S O': 6,
#                                    'S be': 1,
#                                    'S for O': 1,
#                                    'for O': 2,
#                                    'in O S O': 2,
#                                    'past O': 1}),
#                           'xcomp': Counter({'': 20,
#                                    'O': 145,
#                                    'O O': 3,
#                                    'O at O': 1,
#                                    'O by cl': 7,
#                                    'O in O': 5,
#                                    'O in O by cl': 1,
#                                    'O on O': 2,
#                                    'O to O': 1,
#                                    'O with O': 3,
#                                    'at O': 1,
#                                    'by O': 1,
#                                    'by cl': 1,
#                                    'cl': 1,
#                                    'for O': 6,
#                                    'for O by O': 1,
#                                    'in O': 2,
#                                    'in O until O': 1,
#                                    'onto O O': 1,
#                                    'than O': 1,
#                                    'to O': 1,
#                                    'with O': 1})}),
#              'pelletise': defaultdict(collections.Counter,
#                          {'conj': Counter({'O': 1})}),
#              'away': defaultdict(collections.Counter,
#                          {'ROOT': Counter({'O': 1, 'S O in O': 1}),
#                           'advmod': Counter({'': 5})}),
#              ...})
